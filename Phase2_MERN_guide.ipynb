# %% [markdown]
# # Phase 2 Full-Stack MERN Guide Implementation
#
# This notebook outlines the steps to implement the instructions from `Phase2_FullStack_MERN_Visual-Studio2.pdf` in the workspace located at:
#
# `C:\Users\Edrich Josh Mabalot\ej`
#
# Each section corresponds to a portion of the guide, breaking down setup and configuration tasks.

# %%
```python
# Try reading PDF content using PyPDF2
import PyPDF2, os
pdf_path = r"C:\Users\Edrich Josh Mabalot\Downloads\Phase2_FullStack_MERN_Visual-Studio2.pdf"
if os.path.exists(pdf_path):
    reader = PyPDF2.PdfReader(pdf_path)
    text = "\n".join(page.extract_text() or "" for page in reader.pages)
    print(text[:1000])
else:
    print("PDF not found")
```

# %% [markdown]
# ## 1. Environment and Project Setup
#
# Create the project directory, initialize the workspace, install Node.js, MongoDB, and any required global tools.

# %%
```python
# Sample code to create directories and initialize npm
import os, subprocess, sys

root = r"C:\Users\Edrich Josh Mabalot\ej"
os.makedirs(root, exist_ok=True)
# npm initialization should be done via terminal: `npm init -y`
print("Directory created and placeholder for npm init")
```

# %% [markdown]
# ## 2. Backend: Express & MongoDB
#
# Create an Express server inside `backend` folder, set up models and routes, connect to MongoDB with Mongoose.

# %%
```python
backend_dir = os.path.join(root, 'backend')
os.makedirs(backend_dir, exist_ok=True)
with open(os.path.join(backend_dir, 'server.js'), 'w') as f:
    f.write("// placeholder for Express server\n")

print('Backend folder setup placeholder')
```

# %% [markdown]
# ## 3. Frontend: React Application
#
# Initialize a React application inside `client` or `src` folder using `create-react-app` and build components.

# %%
```python
client_dir = os.path.join(root, 'client')
os.makedirs(client_dir, exist_ok=True)
with open(os.path.join(client_dir, 'README.md'), 'w') as f:
    f.write("# React app placeholder\n")

print('React client placeholder created')
```

# %% [markdown]
# ## 4. Visual Studio Code Configuration
#
# Configure `launch.json` and `tasks.json` to run both server and client. Set up ESLint/Prettier.

# %% [markdown]
# ## 5. Running & Testing the MERN App
#
# Instructions to start backend and frontend from integrated terminal and run unit tests.
